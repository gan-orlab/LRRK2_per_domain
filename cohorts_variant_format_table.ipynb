# %%
import pandas as pd

# %%
directory = 'drive/MyDrive/Data'
cohort_name = 'UKBB'

# %%
annovar_path = f'{directory}/{cohort_name}_withgnomad_clinvar.annovar.hg38_multianno.txt'
annovar_df = pd.read_csv(annovar_path, sep='\t')
columns_to_extract = [
    'Chr', 'Start', 'End', 'Ref', 'Alt', 'Func.refGene',
    'GeneDetail.refGene', 'ExonicFunc.refGene', 'AAChange.refGene',
    'CADD_phred', 'CLNSIG', 'gnomad41_genome_AF',
    'gnomad41_genome_AF_asj', 'gnomad41_genome_AF_nfe','avsnp151']

# Extract the relevant columns
annovar_df = annovar_df[columns_to_extract]

# Display the first few rows of the DataFrame
annovar_df.head()
# Out:
#      Chr     Start       End Ref Alt Func.refGene       GeneDetail.refGene  \
# 0  chr12  40225042  40225042   C   T         UTR5       NM_198578:c.-90C>T
# 1  chr12  40225043  40225043   C   G         UTR5       NM_198578:c.-89C>G
# 2  chr12  40225044  40225044   -   G         UTR5  NM_198578:c.-88_-87insG
# 3  chr12  40225046  40225046   G   A         UTR5       NM_198578:c.-86G>A
# 4  chr12  40225047  40225047   G   A         UTR5       NM_198578:c.-85G>A
#
#   ExonicFunc.refGene AAChange.refGene CADD_phred CLNSIG gnomad41_genome_AF  \
# 0                  .                .          .      .                  .
# 1                  .                .          .      .                  .
# 2                  .                .          .      .                  .
# 3                  .                .          .      .                  .
# 4                  .                .          .      .          1.314e-05
#
#   gnomad41_genome_AF_asj gnomad41_genome_AF_nfe      avsnp151
# 0                      .                      .             .
# 1                      .                      .             .
# 2                      .                      .             .
# 3                      .                      .             .
# 4                      0               2.94e-05  rs1020433882

# %%
# Define the path to the freq and counts files
freq_path = f'{directory}/{cohort_name}_MAF.assoc.fisher'
counts_path = f'{directory}/{cohort_name}.assoc.fisher'
freq_df = pd.read_csv(freq_path, sep='\s+')
counts_df = pd.read_csv(counts_path, sep='\s+')

# Format data types to match
freq_df['SNP'] = freq_df['SNP'].astype(str)
counts_df['SNP'] = counts_df['SNP'].astype(str)

# merge the two files
MAF_and_counts_df = pd.merge(counts_df[['CHR', 'SNP', 'BP', 'A1', 'A2', 'C_A', 'C_U']],
                             freq_df[['SNP', 'F_A', 'F_U']],
                             on='SNP')

# Display the first few rows of the merged DataFrame
MAF_and_counts_df.head()
# Out:
#    CHR                  SNP        BP  A1 A2  C_A  C_U  F_A  F_U
# 0   12   chr12_40225042_C_T  40225042   T  C    0    0  0.0  0.0
# 1   12   chr12_40225043_C_G  40225043   G  C    0    0  0.0  0.0
# 2   12  chr12_40225044_C_CG  40225044  CG  C    0    0  0.0  0.0
# 3   12   chr12_40225046_G_A  40225046   A  G    0    0  0.0  0.0
# 4   12   chr12_40225047_G_A  40225047   A  G    0    0  0.0  0.0

# %%
# Count number of rows
print(f'Number of rows: {len(MAF_and_counts_df)}')
# Out:
# Number of rows: 2801

# %%
# Based on CHR, A1 and A2 columns, merge the annovar and MAF_and_counts dataframes
MAF_and_counts_df['CHR'] = MAF_and_counts_df['CHR'].astype(str)
MAF_and_counts_df['A1'] = MAF_and_counts_df['A1'].astype(str)
MAF_and_counts_df['A2'] = MAF_and_counts_df['A2'].astype(str)
annovar_df['Chr'] = annovar_df['Chr'].astype(str)
if cohort_name=='UKBB':
  # remove Chr from 'Chr'
  annovar_df['Chr'] = annovar_df['Chr'].str.replace('chr', '')
annovar_df['Ref'] = annovar_df['Ref'].astype(str)
annovar_df['Alt'] = annovar_df['Alt'].astype(str)
merged_df = pd.merge(annovar_df, MAF_and_counts_df, left_on=['Chr', 'Start', 'Ref', 'Alt'], right_on=['CHR', 'BP', 'A2', 'A1'])
merged_df = merged_df.drop(columns=['CHR', 'BP', 'A1', 'A2'])
# Display the first few rows of the merged DataFrame
merged_df.head()
# Out:
#   Chr     Start       End Ref Alt Func.refGene  GeneDetail.refGene  \
# 0  12  40225042  40225042   C   T         UTR5  NM_198578:c.-90C>T
# 1  12  40225043  40225043   C   G         UTR5  NM_198578:c.-89C>G
# 2  12  40225046  40225046   G   A         UTR5  NM_198578:c.-86G>A
# 3  12  40225047  40225047   G   A         UTR5  NM_198578:c.-85G>A
# 4  12  40225049  40225049   G   A         UTR5  NM_198578:c.-83G>A
#
#   ExonicFunc.refGene AAChange.refGene CADD_phred CLNSIG gnomad41_genome_AF  \
# 0                  .                .          .      .                  .
# 1                  .                .          .      .                  .
# 2                  .                .          .      .                  .
# 3                  .                .          .      .          1.314e-05
# 4                  .                .          .      .                  .
#
#   gnomad41_genome_AF_asj gnomad41_genome_AF_nfe      avsnp151  \
# 0                      .                      .             .
# 1                      .                      .             .
# 2                      .                      .             .
# 3                      0               2.94e-05  rs1020433882
# 4                      .                      .             .
#
#                   SNP  C_A  C_U  F_A  F_U
# 0  chr12_40225042_C_T    0    0  0.0  0.0
# 1  chr12_40225043_C_G    0    0  0.0  0.0
# 2  chr12_40225046_G_A    0    0  0.0  0.0
# 3  chr12_40225047_G_A    0    0  0.0  0.0
# 4  chr12_40225049_G_A    0    0  0.0  0.0

# %%
# Add domain annotation based on BP location
domain_df = pd.read_excel(f'{directory}/LRRK2_GRCh38.xlsx', sheet_name="Sheet2")

domain_df.head()
# Out:
#    Chromosome   Gene   Domain    Column1   Column12 narrow_start narrow_end  \
# 0          12  LRRK2     ARM     100-688    100-688    40225234   40274891
# 1          12  LRRK2     ANK     688-863    688-863    40277916   40284040
# 2          12  LRRK2     LRR    943-1309   943-1309     40294854   40305881
# 3          12  LRRK2  RocCOR   1327-1842  1327-1842    40309151   40313983
# 4          12  LRRK2  Kinase   1879-2138  1879-2138    40323303   40340349
#
#    wide_start  wide_end
# 0    40225153  40277914
# 1    40277915  40284043
# 2    40294854  40305881
# 3    40308486  40322084
# 4    40323249  40351571

# %%
def annotate_domain(row, domain_df):
    for _, domain_row in domain_df.iterrows():
        if domain_row['wide_start'] <= row['Start'] <= domain_row['wide_end']:
            return domain_row['Domain']
    return 'Unknown'

# Annotate domain information of variants
merged_df['Domain'] = merged_df.apply(annotate_domain, axis=1, domain_df=domain_df)

# Display the first few rows of the merged DataFrame
merged_df.head()
# Count each domain group
domain_counts = merged_df['Domain'].value_counts()
print(domain_counts)
# Out:
# Domain
# ARM        759
# RocCOR     454
# Unknown    368
# WD40       365
# LRR        355
# Kinase     277
# ANK        141
# Name: count, dtype: int64

# %%
# Count number of rows
print(f'Number of rows: {len(merged_df)}')

# Show me the unmatched rows from MAF_and_counts_df
unmatched_rows = MAF_and_counts_df[~MAF_and_counts_df['SNP'].isin(merged_df['SNP'])]
unmatched_rows.head()
# This is before the UTR5, intronic, and UTR3 variants are removed
# Out:
# Number of rows: 2719
#    CHR                   SNP        BP  A1   A2  C_A  C_U  F_A       F_U
# 2   12   chr12_40225044_C_CG  40225044  CG    C    0    0  0.0  0.000000
# 60  12    chr12_40225280_G_A  40225280   G    A    0    3  0.0  0.000024
# 77  12   chr12_40225338_T_TA  40225338  TA    T    0    0  0.0  0.000000
# 84  12  chr12_40225529_CTT_C  40225529   C  CTT    0    0  0.0  0.000000
# 86  12   chr12_40225533_T_TC  40225533  TC    T    0    0  0.0  0.000000

# %%
# Remove UTR5, intronic, and UTR3 variants and recount unmatched
merged_df = merged_df[~merged_df['Func.refGene'].isin(['UTR5', 'intronic', 'UTR3'])]
print(f'Number of rows: {len(merged_df)}')

# Count again
unmatched_rows = MAF_and_counts_df[~MAF_and_counts_df['SNP'].isin(merged_df['SNP'])]
unmatched_rows.head()
# This is after the UTR5, intronic, and UTR3 variants are removed
# Count each domain group
domain_counts = merged_df['Domain'].value_counts()
print(domain_counts)
# Out:
# Number of rows: 1519
# Domain
# ARM        473
# RocCOR     285
# WD40       254
# LRR        245
# Kinase     163
# ANK         99
# Name: count, dtype: int64

# %%
# remove Domain == Unknown
merged_df = merged_df[merged_df['Domain'] != 'Unknown']
print(f'Number of rows: {len(merged_df)}')
# Out:
# Number of rows: 1519

# %%
# Make the headers more legible
# Mapping of old headers to new headers without underscores
header_mapping = {
    'Chr': 'Chromosome',
    'Start': 'Start Position',
    'End': 'End Position',
    'Ref': 'Reference Allele',
    'Alt': 'Alternate Allele',
    'Func.refGene': 'Functional Annotation',
    'GeneDetail.refGene': 'outside gene cDNA Change',
    'ExonicFunc.refGene': 'Exonic Function',
    'AAChange.refGene': 'cDNA and Amino Acid Change',
    'CADD_phred': 'CADD v1.7 Phred Score',
    'CLNSIG': 'Clinical Significance (Varsome)',
    'gnomad41_genome_AF': 'gnomAD Allele Frequency',
    'gnomad41_genome_AF_asj': 'gnomAD AF Ashkenazi',
    'gnomad41_genome_AF_nfe': 'gnomAD AF Non Finnish European',
    'avsnp151': 'rsID'
}
merged_df = merged_df.rename(columns=header_mapping)

# Display the first few rows of the merged DataFrame
merged_df.head()
# Out:
#    Chromosome  Start Position  End Position Reference Allele Alternate Allele  \
# 31         12        40225154      40225154                G                A
# 32         12        40225159      40225159                G                A
# 33         12        40225160      40225160                A                G
# 34         12        40225164      40225164                G                C
# 35         12        40225170      40225170                G                A
#
#    Functional Annotation outside gene cDNA Change    Exonic Function  \
# 31                exonic                        .  nonsynonymous SNV
# 32                exonic                        .  nonsynonymous SNV
# 33                exonic                        .  nonsynonymous SNV
# 34                exonic                        .  nonsynonymous SNV
# 35                exonic                        .     synonymous SNV
#
#              cDNA and Amino Acid Change CADD v1.7 Phred Score  ...  \
# 31   LRRK2:NM_198578:exon1:c.G23A:p.G8E                 10.65  ...
# 32  LRRK2:NM_198578:exon1:c.G28A:p.E10K                 15.39  ...
# 33  LRRK2:NM_198578:exon1:c.A29G:p.E10G                 15.15  ...
# 34  LRRK2:NM_198578:exon1:c.G33C:p.E11D                 14.00  ...
# 35  LRRK2:NM_198578:exon1:c.G39A:p.E13E                     .  ...
#
#    gnomAD Allele Frequency gnomAD AF Ashkenazi gnomAD AF Non Finnish European  \
# 31               6.571e-06                   0                              0
# 32                       .                   .                              .
# 33                       .                   .                              .
# 34                       .                   .                              .
# 35                       .                   .                              .
#
#             rsID                 SNP C_A  C_U  F_A       F_U  Domain
# 31  rs1052256144  chr12_40225154_G_A   0    0  0.0  0.000000    ARM
# 32   rs281865040  chr12_40225159_G_A   0    0  0.0  0.000000    ARM
# 33             .  chr12_40225160_A_G   0    0  0.0  0.000000    ARM
# 34             .  chr12_40225164_G_C   0    0  0.0  0.000000    ARM
# 35   rs775407458  chr12_40225170_G_A   0    2  0.0  0.000016    ARM
#
# [5 rows x 21 columns]

# %%
header_mapping_2 = {
    'C_A': 'N (Case)',
    'C_U': 'N (Control)',
    'F_A': 'MAF (Case)',
    'F_U': 'MAF (Control)'
}

merged_df = merged_df.rename(columns=header_mapping_2)
merged_df
# Out:
#      Chromosome  Start Position  End Position Reference Allele  \
# 31           12        40225154      40225154                G
# 32           12        40225159      40225159                G
# 33           12        40225160      40225160                A
# 34           12        40225164      40225164                G
# 35           12        40225170      40225170                G
# ...         ...             ...           ...              ...
# 2692         12        40367733      40367733                G
# 2693         12        40367734      40367734                C
# 2694         12        40367736      40367736                G
# 2695         12        40367737      40367737                A
# 2696         12        40367741      40367741                A
#
#      Alternate Allele Functional Annotation outside gene cDNA Change  \
# 31                  A                exonic                        .
# 32                  A                exonic                        .
# 33                  G                exonic                        .
# 34                  C                exonic                        .
# 35                  A                exonic                        .
# ...               ...                   ...                      ...
# 2692                A                exonic                        .
# 2693                T                exonic                        .
# 2694                A                exonic                        .
# 2695                G                exonic                        .
# 2696                G                exonic                        .
#
#         Exonic Function                cDNA and Amino Acid Change  \
# 31    nonsynonymous SNV        LRRK2:NM_198578:exon1:c.G23A:p.G8E
# 32    nonsynonymous SNV       LRRK2:NM_198578:exon1:c.G28A:p.E10K
# 33    nonsynonymous SNV       LRRK2:NM_198578:exon1:c.A29G:p.E10G
# 34    nonsynonymous SNV       LRRK2:NM_198578:exon1:c.G33C:p.E11D
# 35       synonymous SNV       LRRK2:NM_198578:exon1:c.G39A:p.E13E
# ...                 ...                                       ...
# 2692  nonsynonymous SNV  LRRK2:NM_198578:exon51:c.G7552A:p.A2518T
# 2693  nonsynonymous SNV  LRRK2:NM_198578:exon51:c.C7553T:p.A2518V
# 2694  nonsynonymous SNV  LRRK2:NM_198578:exon51:c.G7555A:p.E2519K
# 2695  nonsynonymous SNV  LRRK2:NM_198578:exon51:c.A7556G:p.E2519G
# 2696     synonymous SNV  LRRK2:NM_198578:exon51:c.A7560G:p.K2520K
#
#      CADD v1.7 Phred Score  ... gnomAD Allele Frequency gnomAD AF Ashkenazi  \
# 31                   10.65  ...               6.571e-06                   0
# 32                   15.39  ...                       .                   .
# 33                   15.15  ...                       .                   .
# 34                   14.00  ...                       .                   .
# 35                       .  ...                       .                   .
# ...                    ...  ...                     ...                 ...
# 2692                 18.07  ...                       .                   .
# 2693                  21.6  ...                       .                   .
# 2694                 16.38  ...                       .                   .
# 2695                 14.60  ...                       .                   .
# 2696                     .  ...                       .                   .
#
#      gnomAD AF Non Finnish European          rsID                 SNP  \
# 31                                0  rs1052256144  chr12_40225154_G_A
# 32                                .   rs281865040  chr12_40225159_G_A
# 33                                .             .  chr12_40225160_A_G
# 34                                .             .  chr12_40225164_G_C
# 35                                .   rs775407458  chr12_40225170_G_A
# ...                             ...           ...                 ...
# 2692                              .   rs755075477  chr12_40367733_G_A
# 2693                              .             .  chr12_40367734_C_T
# 2694                              .             .  chr12_40367736_G_A
# 2695                              .             .  chr12_40367737_A_G
# 2696                              .             .  chr12_40367741_A_G
#
#      N (Case)  N (Control)  MAF (Case)  MAF (Control)  Domain
# 31          0            0         0.0       0.000000    ARM
# 32          0            0         0.0       0.000000    ARM
# 33          0            0         0.0       0.000000    ARM
# 34          0            0         0.0       0.000000    ARM
# 35          0            2         0.0       0.000016    ARM
# ...       ...          ...         ...            ...     ...
# 2692        0            4         0.0       0.000032   WD40
# 2693        0            0         0.0       0.000000   WD40
# 2694        0            0         0.0       0.000000   WD40
# 2695        0            0         0.0       0.000000   WD40
# 2696        0            1         0.0       0.000008   WD40
#
# [1519 rows x 21 columns]

# %%
# Now we organize the cDNA and Amino Acid Change column and separate into cDNA and AA Change separate columns
for index, row in merged_df.iterrows():
    if pd.notna(row['cDNA and Amino Acid Change']):
        split_values = row['cDNA and Amino Acid Change'].split(':')[-2:]
        merged_df.at[index, 'cDNA'] = split_values[0]
        merged_df.at[index, 'Amino Acid Change'] = split_values[1] if len(split_values) > 1 else None

merged_df
# Out:
#      Chromosome  Start Position  End Position Reference Allele  \
# 31           12        40225154      40225154                G
# 32           12        40225159      40225159                G
# 33           12        40225160      40225160                A
# 34           12        40225164      40225164                G
# 35           12        40225170      40225170                G
# ...         ...             ...           ...              ...
# 2692         12        40367733      40367733                G
# 2693         12        40367734      40367734                C
# 2694         12        40367736      40367736                G
# 2695         12        40367737      40367737                A
# 2696         12        40367741      40367741                A
#
#      Alternate Allele Functional Annotation outside gene cDNA Change  \
# 31                  A                exonic                        .
# 32                  A                exonic                        .
# 33                  G                exonic                        .
# 34                  C                exonic                        .
# 35                  A                exonic                        .
# ...               ...                   ...                      ...
# 2692                A                exonic                        .
# 2693                T                exonic                        .
# 2694                A                exonic                        .
# 2695                G                exonic                        .
# 2696                G                exonic                        .
#
#         Exonic Function                cDNA and Amino Acid Change  \
# 31    nonsynonymous SNV        LRRK2:NM_198578:exon1:c.G23A:p.G8E
# 32    nonsynonymous SNV       LRRK2:NM_198578:exon1:c.G28A:p.E10K
# 33    nonsynonymous SNV       LRRK2:NM_198578:exon1:c.A29G:p.E10G
# 34    nonsynonymous SNV       LRRK2:NM_198578:exon1:c.G33C:p.E11D
# 35       synonymous SNV       LRRK2:NM_198578:exon1:c.G39A:p.E13E
# ...                 ...                                       ...
# 2692  nonsynonymous SNV  LRRK2:NM_198578:exon51:c.G7552A:p.A2518T
# 2693  nonsynonymous SNV  LRRK2:NM_198578:exon51:c.C7553T:p.A2518V
# 2694  nonsynonymous SNV  LRRK2:NM_198578:exon51:c.G7555A:p.E2519K
# 2695  nonsynonymous SNV  LRRK2:NM_198578:exon51:c.A7556G:p.E2519G
# 2696     synonymous SNV  LRRK2:NM_198578:exon51:c.A7560G:p.K2520K
#
#      CADD v1.7 Phred Score  ... gnomAD AF Non Finnish European          rsID  \
# 31                   10.65  ...                              0  rs1052256144
# 32                   15.39  ...                              .   rs281865040
# 33                   15.15  ...                              .             .
# 34                   14.00  ...                              .             .
# 35                       .  ...                              .   rs775407458
# ...                    ...  ...                            ...           ...
# 2692                 18.07  ...                              .   rs755075477
# 2693                  21.6  ...                              .             .
# 2694                 16.38  ...                              .             .
# 2695                 14.60  ...                              .             .
# 2696                     .  ...                              .             .
#
#                      SNP N (Case) N (Control) MAF (Case)  MAF (Control)  \
# 31    chr12_40225154_G_A        0           0        0.0       0.000000
# 32    chr12_40225159_G_A        0           0        0.0       0.000000
# 33    chr12_40225160_A_G        0           0        0.0       0.000000
# 34    chr12_40225164_G_C        0           0        0.0       0.000000
# 35    chr12_40225170_G_A        0           2        0.0       0.000016
# ...                  ...      ...         ...        ...            ...
# 2692  chr12_40367733_G_A        0           4        0.0       0.000032
# 2693  chr12_40367734_C_T        0           0        0.0       0.000000
# 2694  chr12_40367736_G_A        0           0        0.0       0.000000
# 2695  chr12_40367737_A_G        0           0        0.0       0.000000
# 2696  chr12_40367741_A_G        0           1        0.0       0.000008
#
#       Domain      cDNA  Amino Acid Change
# 31      ARM     c.G23A              p.G8E
# 32      ARM     c.G28A             p.E10K
# 33      ARM     c.A29G             p.E10G
# 34      ARM     c.G33C             p.E11D
# 35      ARM     c.G39A             p.E13E
# ...      ...       ...                ...
# 2692   WD40   c.G7552A           p.A2518T
# 2693   WD40   c.C7553T           p.A2518V
# 2694   WD40   c.G7555A           p.E2519K
# 2695   WD40   c.A7556G           p.E2519G
# 2696   WD40   c.A7560G           p.K2520K
#
# [1519 rows x 23 columns]

# %%
# Remove variants where both N (Case) and N (Control) are 0

#Count the excluded
excluded_df = merged_df[(merged_df['N (Case)'] == 0) & (merged_df['N (Control)'] == 0)]
print(f'Number of excluded rows: {len(excluded_df)}')


merged_df = merged_df[~((merged_df['N (Case)'] == 0) & (merged_df['N (Control)'] == 0))]
# Out:
# Number of excluded rows: 1065

# %%
# print column names
print(merged_df.columns)
# Out:
# Index(['Chromosome', 'Start Position', 'End Position', 'Reference Allele',
#        'Alternate Allele', 'Functional Annotation', 'outside gene cDNA Change',
#        'Exonic Function', 'cDNA and Amino Acid Change',
#        'CADD v1.7 Phred Score', 'Clinical Significance (Varsome)',
#        'gnomAD Allele Frequency', 'gnomAD AF Ashkenazi',
#        'gnomAD AF Non Finnish European', 'rsID', 'SNP', 'N (Case)',
#        'N (Control)', 'MAF (Case)', 'MAF (Control)', 'Domain', 'cDNA',
#        'Amino Acid Change'],
#       dtype='object')

# %%
# if the "outside gene cDNA Change" column is not empty then split by ":" then pick third element and store it inside the cDNA of that row
for index, row in merged_df.iterrows():
    if pd.notna(row['outside gene cDNA Change']):
        split_values = row['outside gene cDNA Change'].split(':')
        if len(split_values) >= 3:
            merged_df.at[index, 'cDNA'] = split_values[2]
            # print cDNA at index
            print(merged_df.at[index, 'cDNA'])
# Out:
# c.151+1G>A
# c.151+2T>C
# c.838+1G>A
# c.1102-1G>A
# c.1656+1G>A
# c.5015+2T>C
# c.7028+1G>A

# %%
# reorder columns such that
# Domain	Chromosome	Position	Reference Allele	Alternate Allele	cDNA	Amino Acid Change	Functional Annotation	Exonic Function	N (Case)	N (Control)	MAF (Case)	MAF (Control)	CADD Phred Score	Clinical Significance (Varsome)	gnomAD Allele Frequency	gnomAD AF Ashkenazi	gnomAD AF Non Finnish European
ordered_merged_df = merged_df[[
    'Domain', 'Chromosome', 'Start Position', 'Reference Allele',
    'Alternate Allele', 'cDNA', 'Amino Acid Change','rsID', 'Functional Annotation',
    'Exonic Function', 'N (Case)', 'N (Control)', 'MAF (Case)',
    'MAF (Control)', 'CADD v1.7 Phred Score', 'Clinical Significance (Varsome)',
    'gnomAD Allele Frequency', 'gnomAD AF Ashkenazi',
    'gnomAD AF Non Finnish European'
]]

ordered_merged_df.head()
# Out:
#    Domain Chromosome  Start Position Reference Allele Alternate Allele  \
# 35   ARM          12        40225170                G                A
# 36   ARM          12        40225176                T                C
# 40   ARM          12        40225188                G                A
# 50   ARM          12        40225260                G                C
# 53   ARM          12        40225268                C                T
#
#        cDNA Amino Acid Change         rsID Functional Annotation  \
# 35   c.G39A            p.E13E  rs775407458                exonic
# 36   c.T45C            p.T15T  rs142399623                exonic
# 40   c.G57A            p.L19L            .                exonic
# 50  c.G129C            p.L43L  rs550441220                exonic
# 53  c.C137T            p.T46M  rs781394575                exonic
#
#       Exonic Function  N (Case)  N (Control)  MAF (Case)  MAF (Control)  \
# 35     synonymous SNV         0            2    0.000000       0.000016
# 36     synonymous SNV         9           67    0.001578       0.000536
# 40     synonymous SNV         0            2    0.000000       0.000016
# 50     synonymous SNV         0            1    0.000000       0.000008
# 53  nonsynonymous SNV         0            5    0.000000       0.000040
#
#    CADD v1.7 Phred Score Clinical Significance (Varsome)  \
# 35                     .                   Likely_benign
# 36                     .                   Likely_benign
# 40                     .                               .
# 50                     .                   Likely_benign
# 53                 16.95          Uncertain_significance
#
#    gnomAD Allele Frequency gnomAD AF Ashkenazi gnomAD AF Non Finnish European
# 35                       .                   .                              .
# 36                  0.0002                   0                         0.0004
# 40                       .                   .                              .
# 50               1.314e-05                   0                       2.94e-05
# 53               3.286e-05                   0                      5.881e-05

# %%
# save into excel file
ordered_merged_df.to_excel(f'{directory}/{cohort_name}_annotated.xlsx', index=False)
